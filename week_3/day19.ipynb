# %% [markdown]
# #Multiple charts

# %%
import seaborn as sns
import pandas as pd

# %%
sales=pd.read_csv('sales1.csv')
sales.head()
# Out:
#    Row ID  Order ID  Order Date Order Priority  Order Quantity       Sales  \
# 0       1         3  10/13/2010            Low               6    261.5400
# 1      49       293   10/1/2012           High              49  10123.0200
# 2      50       293   10/1/2012           High              27    244.5700
# 3      80       483   7/10/2011           High              30   4965.7595
# 4      85       515   8/28/2010  Not Specified              19    394.2700
#
#    Discount       Ship Mode   Profit  Unit Price  ...       Customer Name  \
# 0      0.04     Regular Air  -213.25       38.94  ...  Muhammed MacIntyre
# 1      0.07  Delivery Truck   457.81      208.16  ...        Barry French
# 2      0.01     Regular Air    46.71        8.69  ...        Barry French
# 3      0.08     Regular Air  1198.97      195.99  ...       Clay Rozendal
# 4      0.08     Regular Air    30.94       21.78  ...      Carlos Soltero
#
#   Province   Region Customer Segment Product Category  \
# ...

# %%
sns.relplot(x="Sales", y="Profit", data=sales, col="Customer Segment",row="Product Category", hue="Order Priority")

# %% [markdown]
# #**Scatter**, **Swarm** **Plot**

# %%
#Scatter plot, Magnitude
sns.catplot(x="Ship Mode", y= "Sales", data= sales, hue="Ship Mode")

# %%
#jitter
sns.catplot(x="Ship Mode", y= "Sales", data= sales, hue="Ship Mode", jitter=False)

# %%
#Swarm Plot:type of scatter plot where the data points are adjusted so that they do not overlap with each other
sns.catplot(x="Ship Mode", y= "Sales", data=sales.query("Profit<1000"and "Sales<500"), kind="swarm")
# Out:
# c:\Users\SHRISTI\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 65.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\SHRISTI\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 76.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\SHRISTI\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 9.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
